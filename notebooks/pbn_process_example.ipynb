# %%
import context
from PIL import Image

# %%
from pbn.process_stream_thumbnail import process
from pbn.preprocess.preprocess import invert_scale_binary

# %%
out = process(
    user_logins=["distortion2"],
    preprocess=lambda im: invert_scale_binary(im, th=110, scale=2),
    dir="./data",
    return_steps=True
)

# %%
out[0]['image_processed']
# Out:
# <PIL.Image.Image image mode=L size=3200x1800>

# %%
print(out[0]['image_text'])
# Out:
# ; dL Kick
#
#
#
# ee
#
#
#
#
#
# a
#
# — p v °
#
# Flask of Crimson Tears +9
#
# mo _
# ye tn * L4 itl 4, t
#
# ys
#
# L.. wv
# PE Teeyalicigus kick hit
# be
#
#
#
# E ‘JallyAchilles rp walking
# P’ + oe °
# Elden Rin
# \ JAR CANNON 72
# Morgott - 2:33:10
# Rold Lift - 2:37:30
# ' Snowfield Skip - 2:50:59
# ° , +10 Jar Cannon -
# Mimic Tear -
# Eldgt Beast
# 1 =
# AF
# A 2 e
#
# (2 9600
# ‘arzanSuplex: $50.00 sus
