# %%
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %%
import os

os.listdir("tests/data")
# Out:
# ['example_screenshots', 'download_tests', '.ipynb_checkpoints']

# %%
with webdriver.Firefox() as driver:
    driver.get("https://www.twitch.tv/distortion2")
    driver.save_screenshot("tests/data/download_tests/test.png")

# %%
from PIL import Image

Image.open("tests/data/download_tests/test.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x862>
